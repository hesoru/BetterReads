# %% [markdown]
# # Generating Initial User-Item Matrix from Pre-Existing GoodReads Ratings

# %% [markdown]
# ### Data Sources:
#
# `goodbooks-10k`: https://github.com/zygmuntz/goodbooks-10k
# - We took a sample of 3625 books (`books.csv`) for our BetterReads database, and all available user ratings (`ratings.csv`) for those books.
#
# `goodreads_descriptions_genres.csv`: https://www.kaggle.com/datasets/ishikajohari/best-books-10k-multi-genre-data
# - We obtained genres and book descriptions for our sample of 3625 books.
#
# ### The initial user-item matrix (generated at the end of this notebook) contains 53423 users and 3625 books from GoodReads.

# %%
import pandas as pd
import pyarrow

# %%
gb_ratings_df = pd.read_csv("data/goodbooks-10k/ratings.csv")
gb_ratings_df.head()

# gb_ratings_df[gb_ratings_df["book_id"] == 5397]
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
gb_books_df = pd.read_csv("data/goodbooks-10k/books.csv")
gb_books_df
# gb_books_df[gb_books_df["work_id"] == 5397]
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# 1      439554934  9.780440e+12  J.K. Rowling, Mary GrandPré
# 2      316015849  9.780316e+12              Stephenie Meyer
# 3       61120081  9.780061e+12                   Harper Lee
# 4      743273567  9.780743e+12          F. Scott Fitzgerald
# ...          ...           ...                          ...
# 9995   441019455  9.780441e+12                Ilona Andrews
# 9996  067973371X  9.780680e+12               Robert A. Caro
# 9997  039330762X  9.780393e+12              Patrick O'Brian
# 9998    61711527  9.780062e+12              Peggy Orenstein
# 9999   375700455  9.780376e+12                  John Keegan
#
#       original_publication_year  \
# 0                        2008.0
# 1                        1997.0
# 2                        2005.0
# 3                        1960.0
# 4                        1925.0
# ...                         ...
# 9995                     2010.0
# 9996                     1990.0
# 9997                     1977.0
# 9998                     2011.0
# 9999                     1998.0
#
#                                          original_title  ... ratings_count  \
# 0                                      The Hunger Games  ...       4780653
# 1              Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                              Twilight  ...       3866839
# 3                                 To Kill a Mockingbird  ...       3198671
# 4                                      The Great Gatsby  ...       2683664
# ...                                                 ...  ...           ...
# 9995                                         Bayou Moon  ...         17204
# 9996                                   Means of Ascent   ...         12582
# 9997                              The Mauritius Command  ...          9421
# 9998  Cinderella Ate My Daughter: Dispatches from th...  ...         11279
# 9999                                The First World War  ...          9162
#
#      work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0               4942365                   155254      66715     127936
# 1               4800065                    75867      75504     101676
# 2               3916824                    95009     456191     436802
# 3               3340896                    72586      60427     117415
# 4               2773745                    51992      86236     197621
# ...                 ...                      ...        ...        ...
# 9995              18856                     1180        105        575
# 9996              12952                      395        303        551
# 9997              10733                      374         11        111
# 9998              11994                     1988        275       1002
# 9999               9700                      364        117        345
#
#       ratings_3  ratings_4  ratings_5  \
# 0        560092    1481305    2706317
# 1        455024    1156318    3011543
# 2        793319     875073    1355439
# 3        446835    1001952    1714267
# 4        606158     936012     947718
# ...         ...        ...        ...
# 9995       3538       7860       6778
# 9996       1737       3389       6972
# 9997       1191       4240       5180
# 9998       3765       4577       2375
# 9999       2031       4138       3069
#
#                                               image_url  \
# 0     https://images.gr-assets.com/books/1447303603m...
# 1     https://images.gr-assets.com/books/1474154022m...
# 2     https://images.gr-assets.com/books/1361039443m...
# 3     https://images.gr-assets.com/books/1361975680m...
# 4     https://images.gr-assets.com/books/1490528560m...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460m...
# 9996  https://s.gr-assets.com/assets/nophoto/book/11...
# 9997  https://images.gr-assets.com/books/1455373531m...
# 9998  https://images.gr-assets.com/books/1279214118m...
# 9999  https://images.gr-assets.com/books/1403194704m...
#
#                                         small_image_url
# 0     https://images.gr-assets.com/books/1447303603s...
# 1     https://images.gr-assets.com/books/1474154022s...
# 2     https://images.gr-assets.com/books/1361039443s...
# 3     https://images.gr-assets.com/books/1361975680s...
# 4     https://images.gr-assets.com/books/1490528560s...
# ...                                                 ...
# 9995  https://images.gr-assets.com/books/1307445460s...
# 9996  https://s.gr-assets.com/assets/nophoto/book/50...
# 9997  https://images.gr-assets.com/books/1455373531s...
# 9998  https://images.gr-assets.com/books/1279214118s...
# 9999  https://images.gr-assets.com/books/1403194704s...
#
# [10000 rows x 23 columns]

# %%
# Merge books and ratings
merged_books_ratings = pd.merge(gb_books_df, gb_ratings_df, left_on='book_id', right_on='book_id', how='inner')
merged_books_ratings.dropna()

merged_books_ratings
# Out:
#          book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 0              1            2767052       2767052  2792775          272
# 1              1            2767052       2767052  2792775          272
# 2              1            2767052       2767052  2792775          272
# 3              1            2767052       2767052  2792775          272
# 4              1            2767052       2767052  2792775          272
# ...          ...                ...           ...      ...          ...
# 5976474    10000               8914          8914    11817           31
# 5976475    10000               8914          8914    11817           31
# 5976476    10000               8914          8914    11817           31
# 5976477    10000               8914          8914    11817           31
# 5976478    10000               8914          8914    11817           31
#
#               isbn        isbn13          authors  original_publication_year  \
# 0        439023483  9.780439e+12  Suzanne Collins                     2008.0
# 1        439023483  9.780439e+12  Suzanne Collins                     2008.0
# 2        439023483  9.780439e+12  Suzanne Collins                     2008.0
# 3        439023483  9.780439e+12  Suzanne Collins                     2008.0
# 4        439023483  9.780439e+12  Suzanne Collins                     2008.0
# ...            ...           ...              ...                        ...
# 5976474  375700455  9.780376e+12      John Keegan                     1998.0
# 5976475  375700455  9.780376e+12      John Keegan                     1998.0
# 5976476  375700455  9.780376e+12      John Keegan                     1998.0
# 5976477  375700455  9.780376e+12      John Keegan                     1998.0
# 5976478  375700455  9.780376e+12      John Keegan                     1998.0
#
#               original_title  ... work_text_reviews_count ratings_1  \
# 0           The Hunger Games  ...                  155254     66715
# 1           The Hunger Games  ...                  155254     66715
# 2           The Hunger Games  ...                  155254     66715
# 3           The Hunger Games  ...                  155254     66715
# 4           The Hunger Games  ...                  155254     66715
# ...                      ...  ...                     ...       ...
# 5976474  The First World War  ...                     364       117
# 5976475  The First World War  ...                     364       117
# 5976476  The First World War  ...                     364       117
# 5976477  The First World War  ...                     364       117
# 5976478  The First World War  ...                     364       117
#
#          ratings_2  ratings_3  ratings_4  ratings_5  \
# 0           127936     560092    1481305    2706317
# 1           127936     560092    1481305    2706317
# 2           127936     560092    1481305    2706317
# 3           127936     560092    1481305    2706317
# 4           127936     560092    1481305    2706317
# ...            ...        ...        ...        ...
# 5976474        345       2031       4138       3069
# 5976475        345       2031       4138       3069
# 5976476        345       2031       4138       3069
# 5976477        345       2031       4138       3069
# 5976478        345       2031       4138       3069
#
#                                                  image_url  \
# 0        https://images.gr-assets.com/books/1447303603m...
# 1        https://images.gr-assets.com/books/1447303603m...
# 2        https://images.gr-assets.com/books/1447303603m...
# 3        https://images.gr-assets.com/books/1447303603m...
# 4        https://images.gr-assets.com/books/1447303603m...
# ...                                                    ...
# 5976474  https://images.gr-assets.com/books/1403194704m...
# 5976475  https://images.gr-assets.com/books/1403194704m...
# 5976476  https://images.gr-assets.com/books/1403194704m...
# 5976477  https://images.gr-assets.com/books/1403194704m...
# 5976478  https://images.gr-assets.com/books/1403194704m...
#
#                                            small_image_url  user_id  rating
# 0        https://images.gr-assets.com/books/1447303603s...     2886       5
# 1        https://images.gr-assets.com/books/1447303603s...     6158       5
# 2        https://images.gr-assets.com/books/1447303603s...     3991       4
# 3        https://images.gr-assets.com/books/1447303603s...     5281       5
# 4        https://images.gr-assets.com/books/1447303603s...     5721       5
# ...                                                    ...      ...     ...
# 5976474  https://images.gr-assets.com/books/1403194704s...    35336       4
# 5976475  https://images.gr-assets.com/books/1403194704s...    17999       3
# 5976476  https://images.gr-assets.com/books/1403194704s...    49007       4
# 5976477  https://images.gr-assets.com/books/1403194704s...    43319       5
# 5976478  https://images.gr-assets.com/books/1403194704s...    48281       4
#
# [5976479 rows x 25 columns]

# %%
merged_books_ratings_cleaned = merged_books_ratings[["isbn", "user_id", "rating"]]
merged_books_ratings_cleaned.head()
# Out:
#         isbn  user_id  rating
# 0  439023483     2886       5
# 1  439023483     6158       5
# 2  439023483     3991       4
# 3  439023483     5281       5
# 4  439023483     5721       5

# %%
# read in better_reads_data_processed.json (processed in BetterReads_Initial_User_Item_Matrix.ipynb)
better_reads_df = pd.read_json("data/better_reads_data_processed.json")
better_reads_df
# Out:
#                                                   title  \
# 0               The Hunger Games (The Hunger Games, #1)
# 1                                 To Kill a Mockingbird
# 2                                      The Great Gatsby
# 3                                The Fault in Our Stars
# 4                                            The Hobbit
# ...                                                 ...
# 3620                                A Theory of Justice
# 3621         The Red Knight (The Traitor Son Cycle, #1)
# 3622  The Time Traveller's Guide to Medieval England...
# 3623          The Everafter War (The Sisters Grimm, #7)
# 3624  Cinderella Ate My Daughter: Dispatches from th...
#
#                                author  publishYear  \
# 0                     Suzanne Collins         2008
# 1                          Harper Lee         1960
# 2                 F. Scott Fitzgerald         1925
# 3                          John Green         2012
# 4                      J.R.R. Tolkien         1937
# ...                               ...          ...
# 3620                       John Rawls         1971
# 3621                   Miles  Cameron         2012
# 3622                     Ian Mortimer         2008
# 3623  Michael Buckley, Peter Ferguson         2009
# 3624                  Peggy Orenstein         2011
#
#                                                   image  \
# 0     https://images.gr-assets.com/books/1447303603m...
# 1     https://images.gr-assets.com/books/1361975680m...
# 2     https://images.gr-assets.com/books/1490528560m...
# 3     https://images.gr-assets.com/books/1360206420m...
# 4     https://images.gr-assets.com/books/1372847500m...
# ...                                                 ...
# 3620  https://s.gr-assets.com/assets/nophoto/book/11...
# 3621  https://images.gr-assets.com/books/1348037761m...
# 3622  https://images.gr-assets.com/books/1328167619m...
# 3623  https://images.gr-assets.com/books/1388278230m...
# 3624  https://images.gr-assets.com/books/1279214118m...
#
#                                             description  \
# 0     Could you survive on your own in the wild, wit...
# 1     The unforgettable novel of a childhood in a sl...
# 2     Alternate Cover Edition ISBN: 0743273567 (ISBN...
# 3     Despite the tumor-shrinking medical miracle th...
# 4     First published over 50 years ago, J.R.R. Tolk...
# ...                                                 ...
# 3620  Since it appeared in 1971, John Rawls's A Theo...
# 3621  Twenty eight florins a month is a huge price t...
# 3622  Imagine you could get into a time machine and ...
# 3623  The Grimm family is caught in the midst of a w...
# 3624  The acclaimed author of the groundbreaking bes...
#
#                                                   genre       ISBN  \
# 0     [Young Adult, Fiction, Dystopia, Fantasy, Scie...  439023483
# 1     [Classics, Fiction, Historical Fiction, School...   61120081
# 2     [Classics, Fiction, School, Historical Fiction...  743273567
# 3     [Young Adult, Romance, Fiction, Contemporary, ...  525478817
# 4     [Fantasy, Graphic Novels, Classics, Fiction, C...  618260307
# ...                                                 ...        ...
# 3620  [Philosophy, Politics, Nonfiction, Law, Classi...  674017722
# 3621  [Fantasy, Epic Fantasy, Fiction, High Fantasy,...  575113294
# 3622  [History, Nonfiction, Medieval, Historical, Br...  224079948
# 3623  [Fantasy, Middle Grade, Fairy Tales, Mystery, ...  810983559
# 3624  [Nonfiction, Parenting, Feminism, Psychology, ...   61711527
#
#       numberOfEditions  averageRating  ratingsCount  reviewCount
# 0                  272           4.34       4780653       155254
# 1                  487           4.25       3198671        72586
# 2                 1356           3.89       2683664        51992
# 3                  226           4.26       2346404       140739
# 4                  969           4.25       2071616        37653
# ...                ...            ...           ...          ...
# 3620                44           3.91          8472          168
# 3621                26           4.12          8556          742
# 3622                27           3.99          9824          970
# 3623                 2           4.32         12493          455
# 3624                 7           3.65         11279         1988
#
# [3625 rows x 11 columns]

# %%
# keep just the ratings for the 3625 books in the betterreads database
reduced_merged_books_ratings = pd.merge(better_reads_df, merged_books_ratings_cleaned, left_on='ISBN', right_on='isbn', how='inner')
reduced_merged_books_ratings_cleaned = reduced_merged_books_ratings[["isbn", "user_id", "rating"]]
reduced_merged_books_ratings_cleaned
# Out:
#               isbn  user_id  rating
# 0        439023483     2886       5
# 1        439023483     6158       5
# 2        439023483     3991       4
# 3        439023483     5281       5
# 4        439023483     5721       5
# ...            ...      ...     ...
# 3809350   61711527    22360       4
# 3809351   61711527    13990       3
# 3809352   61711527    24615       5
# 3809353   61711527    47930       4
# 3809354   61711527    35560       2
#
# [3809355 rows x 3 columns]

# %%
# read in ISBN to book_id mappings generated from script (better-reads/backend/scripts/getBookIdToIsbnMap.js) run on MongoDB database
isbn_book_id = pd.read_json("data/bookIdToIsbnMap.json")
isbn_book_id
# Out:
#                        6861eac7f73dac107c42d926 6861eac7f73dac107c42d927  \
# ISBN                                  439023483                 61120081
# title   The Hunger Games (The Hunger Games, #1)    To Kill a Mockingbird
# author                          Suzanne Collins               Harper Lee
#
#        6861eac7f73dac107c42d928 6861eac7f73dac107c42d929  \
# ISBN                  743273567                525478817
# title          The Great Gatsby   The Fault in Our Stars
# author      F. Scott Fitzgerald               John Green
#
#        6861eac7f73dac107c42d92a 6861eac7f73dac107c42d92b  \
# ISBN                  618260307                316769177
# title                The Hobbit   The Catcher in the Rye
# author           J.R.R. Tolkien            J.D. Salinger
#
#        6861eac7f73dac107c42d92c 6861eac7f73dac107c42d92d  \
# ISBN                  679783261               1594480001
# title       Pride and Prejudice          The Kite Runner
# author              Jane Austen          Khaled Hosseini
#
#          6861eac7f73dac107c42d92e                 6861eac7f73dac107c42d92f  \
# ISBN                     62024035                                451524934
# title   Divergent (Divergent, #1)                                     1984
# author              Veronica Roth  George Orwell, Erich Fromm, Celâl Üster
#
#         ...                           6861eac7f73dac107c42e745  \
# ISBN    ...                                          739416383
# title   ...  The Prize Winner of Defiance, Ohio: How My Mot...
# author  ...                                         Terry Ryan
#
#         6861eac7f73dac107c42e746             6861eac7f73dac107c42e747  \
# ISBN                   679749845                           1580050751
# title   The Comfort of Strangers  Cunt: A Declaration of Independence
# author                Ian McEwan            Inga Muscio, Betty Dodson
#
#                            6861eac7f73dac107c42e748 6861eac7f73dac107c42e749  \
# ISBN                                      679750150                140255087
# title   The Sailor Who Fell from Grace with the Sea         The Snow Leopard
# author                   Yukio Mishima, John Nathan        Peter Matthiessen
#
#        6861eac7f73dac107c42e74a                    6861eac7f73dac107c42e74b  \
# ISBN                  674017722                                   575113294
# title       A Theory of Justice  The Red Knight (The Traitor Son Cycle, #1)
# author               John Rawls                              Miles  Cameron
#
#                                  6861eac7f73dac107c42e74c  \
# ISBN                                            224079948
# title   The Time Traveller's Guide to Medieval England...
# author                                       Ian Mortimer
#
#                          6861eac7f73dac107c42e74d  \
# ISBN                                    810983559
# title   The Everafter War (The Sisters Grimm, #7)
# author            Michael Buckley, Peter Ferguson
#
#                                  6861eac7f73dac107c42e74e
# ISBN                                             61711527
# title   Cinderella Ate My Daughter: Dispatches from th...
# author                                    Peggy Orenstein
#
# [3 rows x 3625 columns]

# %%
# transpose mapping so ISBN and book_id are in their own columns
isbn_book_id_trans = isbn_book_id.T
isbn_book_id_map = isbn_book_id_trans.reset_index()
isbn_book_id_map
# Out:
#                          index       ISBN  \
# 0     6861eac7f73dac107c42d926  439023483
# 1     6861eac7f73dac107c42d927   61120081
# 2     6861eac7f73dac107c42d928  743273567
# 3     6861eac7f73dac107c42d929  525478817
# 4     6861eac7f73dac107c42d92a  618260307
# ...                        ...        ...
# 3620  6861eac7f73dac107c42e74a  674017722
# 3621  6861eac7f73dac107c42e74b  575113294
# 3622  6861eac7f73dac107c42e74c  224079948
# 3623  6861eac7f73dac107c42e74d  810983559
# 3624  6861eac7f73dac107c42e74e   61711527
#
#                                                   title  \
# 0               The Hunger Games (The Hunger Games, #1)
# 1                                 To Kill a Mockingbird
# 2                                      The Great Gatsby
# 3                                The Fault in Our Stars
# 4                                            The Hobbit
# ...                                                 ...
# 3620                                A Theory of Justice
# 3621         The Red Knight (The Traitor Son Cycle, #1)
# 3622  The Time Traveller's Guide to Medieval England...
# 3623          The Everafter War (The Sisters Grimm, #7)
# 3624  Cinderella Ate My Daughter: Dispatches from th...
#
#                                author
# 0                     Suzanne Collins
# 1                          Harper Lee
# 2                 F. Scott Fitzgerald
# 3                          John Green
# 4                      J.R.R. Tolkien
# ...                               ...
# 3620                       John Rawls
# 3621                   Miles  Cameron
# 3622                     Ian Mortimer
# 3623  Michael Buckley, Peter Ferguson
# 3624                  Peggy Orenstein
#
# [3625 rows x 4 columns]

# %%
# replace ISBN with MongoDB book_id
reduced_merged_books_ratings_book_id = pd.merge(reduced_merged_books_ratings_cleaned, isbn_book_id_map, left_on='isbn', right_on='ISBN', how='inner')
reduced_merged_books_ratings_book_id
ratings_books = reduced_merged_books_ratings_book_id[["index", "user_id", "rating"]]
ratings_books = ratings_books.rename(columns={'index': 'book_id'})
ratings_books
# Out:
#                           book_id  user_id  rating
# 0        6861eac7f73dac107c42d926     2886       5
# 1        6861eac7f73dac107c42d926     6158       5
# 2        6861eac7f73dac107c42d926     3991       4
# 3        6861eac7f73dac107c42d926     5281       5
# 4        6861eac7f73dac107c42d926     5721       5
# ...                           ...      ...     ...
# 3809350  6861eac7f73dac107c42e74e    22360       4
# 3809351  6861eac7f73dac107c42e74e    13990       3
# 3809352  6861eac7f73dac107c42e74e    24615       5
# 3809353  6861eac7f73dac107c42e74e    47930       4
# 3809354  6861eac7f73dac107c42e74e    35560       2
#
# [3809355 rows x 3 columns]

# %%
# Pivot mapping dataframe to user-item matrix
matrix = ratings_books.pivot_table(index="user_id", columns="book_id", values="rating").fillna(0)
matrix.shape
# Out:
# (53423, 3625)

# %%
# export user-item matrix created from goodreads dataset
# matrix.to_json("data/initial-user-item-matrix.json")

# %%
# export user-item matrix created from goodreads dataset to parquet (more space- and time- efficient than json)
matrix.to_parquet("data/initial-user-item-matrix.parquet", engine="pyarrow")
